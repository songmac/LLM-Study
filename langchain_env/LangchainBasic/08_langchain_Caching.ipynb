# %% [markdown]
# # LangSmith API Key 로드

# %%
# API KEY를 환경변수로 관리하기 위한 설정 파일
from dotenv import load_dotenv

# API KEY 정보로드
load_dotenv()
# Out:
# True

# %% [markdown]
# # Langsmith로 프로젝트 추적 설정

# %%
from utils import logging

logging.langsmith("Caching")
# Out:
# LangSmith 추적을 시작합니다.
# [프로젝트명]
# Caching

# %% [markdown]
# # 캐싱 (Caching)

# %% [markdown]
# LangChain은 LLM을 위한 선택적 캐싱 레이어를 제공합니다.
#
# 이는 두 가지 이유로 유용합니다.
#
# 동일한 완료를 여러 번 요청하는 경우 LLM 공급자에 대한 API 호출 횟수를 줄여 비용을 절감할 수 있습니다.
#
# LLM 제공업체에 대한 API 호출 횟수를 줄여 애플리케이션의 속도를 높일 수 있습니다.

# %% [markdown]
# ## 기본 프롬프트 입력

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate

# 모델을 생성합니다.
llm = ChatOpenAI(model_name="gpt-3.5-turbo")

# 프롬프트를 생성합니다.
prompt = PromptTemplate.from_template("{country} 에 대해서 200자 내외로 요약해줘")

# 체인을 생성합니다.
chain = prompt | llm

# %%
# %%time 
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 국가로, 서울이 수도이다. 경제적으로 선진국가로 발전하였으며 기술적 혁신과 K-pop, K-drama 등의 문화 콘텐츠로 세계적으로 유명하다. 전통문화와 현대문화가 공존하는 나라로, 한복과 한식뿐만 아니라 현대 건축물과 패션 등도 독특하다. 한반도 분단으로 남북한 간에 여전히 긴장 관계가 이어지고 있지만, 최근 남북 관계가 개선되고 있으며 평화와 통일을 향한 노력을 계속하고 있다. 또한, 한류 열풍으로 한국문화에 대한 세계적인 관심이 높아지고 있다.
# CPU times: total: 46.9 ms
# Wall time: 4.49 s

# %% [markdown]
# ## InMemoryCache

# %% [markdown]
# pip install -U langchain-community

# %%
# %%time
from langchain.globals import set_llm_cache
from langchain.cache import InMemoryCache

# 인메모리 캐시를 사용합니다.
set_llm_cache(InMemoryCache())

# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도 ...
# CPU times: total: 141 ms
# Wall time: 58.6 s

# %%
# %%time
# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도로 발전한 고도 ...
# CPU times: total: 0 ns
# Wall time: 8.87 ms

# %% [markdown]
# ## SQLite Cache

# %%
from langchain.cache import SQLiteCache
from langchain.globals import set_llm_cache
import os

# 캐시 디렉토리를 생성합니다.
if not os.path.exists("cache"):
    os.makedirs("cache")

# SQLiteCache를 사용합니다.
set_llm_cache(SQLiteCache(database_path="cache/llm_cache.db"))

# %%
# %%time 
# 체인을 실행합니다.
response = chain.invoke({"country": "한국"})
print(response.content)
# Out:
# 한국은 동아시아에 위치한 나라로, 서울을 수도로 하는 대한민국과 평양을 수도로 하는 북한으로 구성되어 있다. 한반도에 위치하며, 주요 언어는 한국어이다. 한국은 역사적으로 고려, 조선 등 다양한 왕조 시대를 거쳐 왔으며, 현재는 선진화된 IT 기술과 문화 산업으로 유명하다. 또한, 한류 열풍으로 한국의 대중문화는 세계적으로 널리 알려져 있으며, K-pop, K-drama 등이 전 세계적으로 사랑받고 있다. 또한, 한국은 빠르게 발전하는 경제와 뛰어난 교육 시스템으로 유명하며, 전통문화와 현대문화가 조화롭게 공존하는 나라이다.
# CPU times: total: 0 ns
# Wall time: 4.35 s
