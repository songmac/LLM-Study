# %% [markdown]
# # Settings

# %% [raw]
# pip install pandas scikit-learn

# %% [markdown]
# # 네이버 웹검색 API

# %%
# 변수 설명:
# client_id: 네이버 API 클라이언트 ID
# client_secret: 네이버 API 클라이언트 시크릿 키
# query: 검색할 키워드 (사용자 입력 값을 URL 인코딩하여 저장)
# idx: 데이터프레임에 저장할 데이터의 인덱스를 추적하는 변수
# display: 한 번의 요청에 가져올 검색 결과의 개수 (최대 100)
# start: 검색 결과의 시작 인덱스
# end: 검색할 페이지의 마지막 인덱스 (총 몇 개의 검색 결과를 가져올지)
# web_df: 검색 결과를 저장할 Pandas DataFrame (열: "Title", "Link", "Description")

import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "S00Vm493qDs_B4TUvI6l"
client_secret = "DXmgZkrRmT"

keyword = input("검색어: ")
query = urllib.parse.quote(keyword)
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description"))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/webkr?query=" + query + "&display=" + str(display) + "&start=" + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            web_df.loc[idx] = [title, link, description]
            idx += 1
    else:
        print("Error Code:" + str(rescode))

# web_df 데이터프레임 출력
web_df
# Out:
#                               Title  \
# 0                    딸기 - 두산백과 두피디아
# 1                         딸기 - 나무위키
# 2                     딸기 - 위키백과 한국어
# 3                      딸기 - 농식품백과사전
# 4                         딸기 - 쿡쿡TV
# ..                              ...
# 145                 딸기 - 무료 벡터 | 제목
# 146  사이언스온 - 딸기는 씻었으나 배열은 흐트러지지 않았다
# 147                 딸기 - 무료 벡터 | 제목
# 148                      무료 사진 | 제목
# 149             딸기 Archives - 코메디닷컴
#
#                                                   Link  \
# 0    https://terms.naver.com/entry.naver?docId=1086...
# 1               https://namu.wiki/w/%EB%94%B8%EA%B8%B0
# 2     https://ko.wikipedia.org/wiki/%EB%94%B8%EA%B8%B0
# 3    https://terms.naver.com/entry.naver?docId=2834...
# 4    https://terms.naver.com/entry.naver?docId=1993...
# ..                                                 ...
# 145  https://ko.ac-illust.com/clip-art/526650/%EB%9...
# 146                 http://scienceon.hani.co.kr/170425
# 147  https://ko.ac-illust.com/clip-art/863305/%EB%9...
# 148  https://ko.photo-ac.com/photo/47416/%EB%94%B8%...
# 149    https://kormedi.com/amp/tag/%EB%94%B8%EA%B8%B0/
#
#                                            Description
# 0    쌍떡잎식물 이판화군 장미목 장미과의 여러해살이풀. 잎자루는 길고 비교적 큰 3개의 ...
# 1    🍓 / Strawberry 딸기는 쌍떡잎식물의 이판화군 장미목 장미과의 여러해살이풀...
# 2    딸기 ( 영어: strawberry 또는 garden strawberry , 학명:...
# 3    장미과(薔薇科 Rosaceae) 땃딸기속(―屬 Fragaria)에 속하는 8종(種)...
# 4    봄이면 빠질 수 없는 딸기! 향도 달콤, 맛도 달콤한 딸기로 스펀지케이크, 비타민 ...
# ..                                                 ...
# 145  무료로 딸기 로열티 프리 벡터, 클립아트 또는 일러스트레이션을 다운로드하십시오. 상...
# 146                   #7. 딸기 파티 딸기파티 시즌이다. 학생복지위원회에...
# 147  무료로 딸기 로열티 프리 벡터, 클립아트 또는 일러스트레이션을 다운로드하십시오. 상...
# 148              무료 딸기 사진을 다운로드하세요. 최고의 무료 딸기 이미지와 사진.
# 149  Browsing tag 딸기 강렬한 붉은색 과일과 야채는 보기에도... 과일은 ‘딸...
#
# [150 rows x 3 columns]

# %% [markdown]
# ### 웹 검색 결과 저장

# %%
# DataFrame을 CSV 파일로 저장
web_df.to_csv(f"web_df_{keyword}.csv", index=False)

# %% [markdown]
# ### 결과 요약

# %%
# 변수 설명:
# client_id: 네이버 API 클라이언트 ID
# client_secret: 네이버 API 클라이언트 시크릿 키
# query: 검색할 키워드 (사용자 입력 값을 URL 인코딩하여 저장)
# idx: 데이터프레임에 저장할 데이터의 인덱스를 추적하는 변수
# display: 한 번의 요청에 가져올 검색 결과의 개수 (최대 100)
# start: 검색 결과의 시작 인덱스
# end: 검색할 페이지의 마지막 인덱스 (총 몇 개의 검색 결과를 가져올지)
# web_df: 검색 결과를 저장할 Pandas DataFrame (열: "Title", "Link", "Description")

import os
import openai
import sys
import urllib.request
import pandas as pd
import json
import re
from dotenv import load_dotenv 
# API KEY 정보를 불러옵니다
load_dotenv('./credentials/.env')

api_key = os.environ.get("OPENAI_API_KEY")
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

# OpenAI GPT 요약 함수 정의 (한국어)
def summarize_text(text):
    openai.api_key = api_key
    completion = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "당신은 텍스트를 요약해주는 유용한 조수입니다."},
            {"role": "user", "content": f"다음 텍스트를 요약해 주세요:\n\n{text}"}
        ]
    )
    return completion.choices[0].message.content

keyword = input("검색어: ")
query = urllib.parse.quote(keyword)
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=("Title", "Link", "Description", "Summary"))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/webkr?query=" + query + "&display=" + str(display) + "&start=" + str(start_index)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            # 요약 추가 
            summary = summarize_text(description)
            
            web_df.loc[idx] = [title, link, description, summary]
            idx += 1
    else:
        print("Error Code:" + str(rescode))

# web_df 데이터프레임 출력
web_df
# Out:
#                               Title  \
# 0                    딸기 - 두산백과 두피디아
# 1                         딸기 - 나무위키
# 2                     딸기 - 위키백과 한국어
# 3                      딸기 - 농식품백과사전
# 4                         딸기 - 쿡쿡TV
# ..                              ...
# 145                           요거프레소
# 146  사이언스온 - 딸기는 씻었으나 배열은 흐트러지지 않았다
# 147                 딸기 - 무료 벡터 | 제목
# 148                      무료 사진 | 제목
# 149             딸기 Archives - 코메디닷컴
#
#                                                   Link  \
# 0    https://terms.naver.com/entry.naver?docId=1086...
# 1               https://namu.wiki/w/%EB%94%B8%EA%B8%B0
# 2     https://ko.wikipedia.org/wiki/%EB%94%B8%EA%B8%B0
# 3    https://terms.naver.com/entry.naver?docId=2834...
# 4    https://terms.naver.com/entry.naver?docId=1993...
# ..                                                 ...
# 145                     https://www.yogerpresso.co.kr/
# 146                 http://scienceon.hani.co.kr/170425
# 147  https://ko.ac-illust.com/clip-art/863305/%EB%9...
# 148  https://ko.photo-ac.com/photo/47416/%EB%94%B8%...
# 149    https://kormedi.com/amp/tag/%EB%94%B8%EA%B8%B0/
#
#                                            Description  \
# 0    쌍떡잎식물 이판화군 장미목 장미과의 여러해살이풀. 잎자루는 길고 비교적 큰 3개의 ...
# 1    🍓 / Strawberry 딸기는 쌍떡잎식물의 이판화군 장미목 장미과의 여러해살이풀...
# 2    딸기 ( 영어: strawberry 또는 garden strawberry , 학명:...
# 3    장미과(薔薇科 Rosaceae) 땃딸기속(―屬 Fragaria)에 속하는 8종(種)...
# 4    봄이면 빠질 수 없는 딸기! 향도 달콤, 맛도 달콤한 딸기로 스펀지케이크, 비타민 ...
# ..                                                 ...
# 145      프리미엄 디저트 카페, 프랜차이즈, 바리스타 아카데미 운영, 가맹점 개설절차 안내
# 146                   #7. 딸기 파티 딸기파티 시즌이다. 학생복지위원회에...
# 147  무료로 딸기 로열티 프리 벡터, 클립아트 또는 일러스트레이션을 다운로드하십시오. 상...
# 148              무료 딸기 사진을 다운로드하세요. 최고의 무료 딸기 이미지와 사진.
# 149  Browsing tag 딸기 강렬한 붉은색 과일과 야채는 보기에도... 과일은 ‘딸...
#
#                                                Summary
# 0    장미과 식물로 봄에 흰색 꽃이 핀다. 잎은 길고 둥글며 톱니 모양이다. 종종 여러해...
# 1    텍스트를 요약하면, "딸기는 여러해살이풀이며, 쌍떡잎식물 중 장미과에 속하는 열매를...
# 2    딸기는 장미과 딸기속에 속하는 과채류로, 산딸기, 뱀딸기, 야생딸기 등과 재배하는 ...
# 3    장미과 속 땃딸기속에 속하는 8종의 열매식물은 다년생이며 숙근성을 가지고 있습니다....
# 4    봄에는 딸기가 매력적입니다. 딸기는 달콤한 향과 맛으로 유명하며, 스펀지케이크나 비...
# ..                                                 ...
# 145  텍스트는 프리미엄 디저트 카페 프랜차이즈와 바리스타 아카데미의 운영 및 가맹점 개설...
# 146  텍스트 요약: 딸기 파티 시즌이 돌아왔고, 학생복지위원회에서 주최하는 딸기 파티가 ...
# 147  텍스트는 딸기 관련 로열티 프리 벡터, 클립아트 및 일러스트레이션을 무료로 다운로드...
# 148                무료로 최고의 딸기 이미지와 사진을 다운로드 받을 수 있습니다.
# 149  요약: 2020년부터 딸기와 포도의 매출이 증가하여, 이 두 과일이 사과와 감귤을 ...
#
# [150 rows x 4 columns]

# %%
# DataFrame을 CSV 파일로 저장
web_df.to_csv(f"web_df_summary_{keyword}.csv", index=False)

# %% [markdown]
# ### 상위 10개의 키워드 추출 (예정)

# %% [markdown]
# ### 키워드에 대한 긍정/부정 반응에 대한 워드클라우드 (예정)

# %% [markdown]
# # 네이버 뉴스 검색 API

# %%
# 변수 설명:
# client_id: 네이버 API 클라이언트 ID
# client_secret: 네이버 API 클라이언트 시크릿 키
# query: 검색할 키워드 (사용자 입력 값을 URL 인코딩하여 저장)
# idx: 데이터프레임에 저장할 데이터의 인덱스를 추적하는 변수
# display: 한 번의 요청에 가져올 검색 결과의 개수 (최대 100)
# start: 검색 결과의 시작 인덱스
# end: 검색할 페이지의 마지막 인덱스 (총 몇 개의 검색 결과를 가져올지)
# sort: 검색 결과를 정렬하는 기준 (sim: 유사도, date: 날짜 순)
# news_df: 검색 결과를 저장할 Pandas DataFrame (열: "Title", "Original Link", "Link", "Description", "Publication Date")

import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "S00Vm493qDs_B4TUvI6l"
client_secret = "DXmgZkrRmT"

keyword = input("검색어: ")
query = urllib.parse.quote(keyword)
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "Publication Date"))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/news?query=" + query + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    
    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pub_date = re.sub(remove_tag, '', items[item_index]['pubDate'])
            
            news_df.loc[idx] = [title, original_link, link, description, pub_date]
            idx += 1
    else:
        print("Error Code:" + str(rescode))

# news_df 데이터프레임 출력
news_df
# Out:
#                                           Title  \
# 0              밀양시, 딸기 재배 선구자 '고 송준생 선생' 공로패 헌정
# 1               밀양시, 국내 딸기 시배 유공자 고 송준생 선생에 공로패
# 2    밀양시, 대한민국 딸기 첫 재배 선구자 ‘故 송준생 선생’에 공로패 헌...
# 3                밀양시, 딸기 시배 유공자 故 송준생 선생 공로패 헌정
# 4                밀양시, 딸기 시배 유공자 故 송준생 선생 공로패 헌정
# ..                                          ...
# 995         [포토뉴스]권재한 농진청장, 딸기와 상추 '사이짓기' 농가 찾아
# 996         딸기·포도·커피…“쓴맛 내는 폴리페놀 함유 식품, 천연 오젬픽”
# 997            공주시, 폭염 대비 딸기 육묘 시기 병해충 철저 관리 당부
# 998                공주시, 폭염 딸기 육묘시기 병해충 철저 관리 당부
# 999           경북 고령군, 2024년 귀농인 영농정착 전문기술 교육 개강
#
#                                          Original Link  \
# 0    https://www.yna.co.kr/view/AKR2024100214380005...
# 1    https://www.news1.kr/local/busan-gyeongnam/555...
# 2       https://www.nongmin.com/article/20241002500366
# 3    https://www.nocutnews.co.kr/news/6221828?utm_s...
# 4    http://www.gndomin.com/news/articleView.html?i...
# ..                                                 ...
# 995  https://news.bbsi.co.kr/news/articleView.html?...
# 996  https://www.donga.com/news/article/all/2024082...
# 997     http://news.tf.co.kr/read/national/2122513.htm
# 998  https://www.joongdo.co.kr/web/view.php?key=202...
# 999  http://www.aflnews.co.kr/news/articleView.html...
#
#                                                   Link  \
# 0    https://n.news.naver.com/mnews/article/001/001...
# 1    https://n.news.naver.com/mnews/article/421/000...
# 2    https://n.news.naver.com/mnews/article/662/000...
# 3    https://n.news.naver.com/mnews/article/079/000...
# 4    http://www.gndomin.com/news/articleView.html?i...
# ..                                                 ...
# 995  https://news.bbsi.co.kr/news/articleView.html?...
# 996  https://n.news.naver.com/mnews/article/020/000...
# 997  https://n.news.naver.com/mnews/article/629/000...
# 998  https://www.joongdo.co.kr/web/view.php?key=202...
# 999  http://www.aflnews.co.kr/news/articleView.html...
#
#                                            Description  \
# 0    대한민국 딸기 시배지인 경남 밀양시는 2일 시청 시장실에서 국내 처음으로 딸기를 재...
# 1    경남 밀양시가 국내 딸기 시배 유공자인 고 송준생 선생에게 공로패를 헌정했다. 시는...
# 2    경남 밀양시(시장 안병구)는 2일 시장실에서 우리나라에서 처음으로 딸기를 재배해 딸...
# 3    밀양시가 우리나라에서 처음으로 딸기를 재배해 딸기 농업의 기틀을 마련한 고(故) 송...
# 4    /밀양시 밀양시는 2일 시청 시장실에서 우리나라에서 처음으로 딸기를 재배해 딸기 농...
# ..                                                 ...
# 995  권재한 농촌진흥청장(가운데)은 6일 충남 논산시 성동면 상추 수경재배 농가를 찾아 ...
# 996  폴리페놀은 딸기(스트로베리) 블루베리, 라즈 베리 등의 베리류, 적포도, 석류, 올...
# 997  최원철)가 딸기 육묘 시기와 긴 장마 이후 폭염 기간이 맞물림에 따라 불량한 환경조...
# 998  공주시가 딸기 육묘 시기 긴 장마 이후 폭염 기간이 맞물림에 따라 불량한 환경조건에...
# 999  이번 전문기술 교육은 딸기, 토마토를 주력으로 10월 15일까지 주1~2회씩 총 1...
#
#                     Publication Date
# 0    Wed, 02 Oct 2024 16:58:00 +0900
# 1    Wed, 02 Oct 2024 18:07:00 +0900
# 2    Wed, 02 Oct 2024 17:20:00 +0900
# 3    Wed, 02 Oct 2024 17:25:00 +0900
# 4    Thu, 03 Oct 2024 17:30:00 +0900
# ..                               ...
# 995  Tue, 06 Aug 2024 17:10:00 +0900
# 996  Mon, 26 Aug 2024 10:01:00 +0900
# 997  Tue, 06 Aug 2024 11:46:00 +0900
# 998  Tue, 06 Aug 2024 10:44:00 +0900
# 999  Wed, 11 Sep 2024 09:12:00 +0900
#
# [1000 rows x 5 columns]

# %% [markdown]
# ### 뉴스 검색 결과 저장

# %%
# DataFrame을 CSV 파일로 저장
news_df.to_csv(f"news_df_{keyword}.csv", index=False)

# %% [markdown]
# ### 뉴스 결과 요약

# %%
import os
import openai
import sys
import urllib.request
import pandas as pd
import json
import re
from dotenv import load_dotenv 
# API KEY 정보를 불러옵니다
load_dotenv('./credentials/.env')

api_key = os.environ.get("OPENAI_API_KEY")
client_id = os.environ.get("CLIENT_ID")
client_secret = os.environ.get("CLIENT_SECRET")

# OpenAI GPT 요약 함수 정의 (100자 이내)
def summarize_text(text):
    openai.api_key = api_key
    completion = openai.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": "당신은 텍스트를 한 문단으로 요약해주는 유용한 조수입니다."},
            {"role": "user", "content": f"다음 텍스트를 199자 이내로 한 문단으로 요약해 주세요:\n\n{text}"}
        ]
    )
    return completion.choices[0].message.content


keyword = input("검색어: ")
query = urllib.parse.quote(keyword)
idx = 0
display = 100
start = 1
end = 1000
sort = "sim"

news_df = pd.DataFrame(columns=("Title", "Original Link", "Link", "Description", "Publication Date", "Summary"))

for start_index in range(start, end, display):
    url = "https://openapi.naver.com/v1/search/news?query=" + query + "&display=" + str(display) + "&start=" + str(start_index) + "&sort=" + sort

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)

    response = urllib.request.urlopen(request)
    rescode = response.getcode()

    if rescode == 200:
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']

        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag, '', items[item_index]['title'])
            original_link = items[item_index]['originallink']
            link = items[item_index]['link']
            description = re.sub(remove_tag, '', items[item_index]['description'])
            pub_date = re.sub(remove_tag, '', items[item_index]['pubDate'])
            
            # 요약 추가 (100자 이내 한 문단)
            summary = summarize_text(description)
            
            news_df.loc[idx] = [title, original_link, link, description, pub_date, summary]
            idx += 1
    else:
        print("Error Code:" + str(rescode))

# news_df 데이터프레임 출력
news_df
# Out:
#                                           Title  \
# 0              밀양시, 딸기 재배 선구자 '고 송준생 선생' 공로패 헌정
# 1               밀양시, 국내 딸기 시배 유공자 고 송준생 선생에 공로패
# 2    밀양시, 대한민국 딸기 첫 재배 선구자 ‘故 송준생 선생’에 공로패 헌...
# 3                밀양시, 딸기 시배 유공자 故 송준생 선생 공로패 헌정
# 4                밀양시, 딸기 시배 유공자 故 송준생 선생 공로패 헌정
# ..                                          ...
# 995                       전국 농촌지도자들 농업 미래 비전 모색
# 996                   충북대 뮤즈 총동아리연합회, 딸기 농가서 봉사
# 997                산청군, 딸기 삽목 육모 신기술 도입 효과 '톡톡'
# 998                      산청군, 딸기 재배 신기술 ‘반응 좋네’
# 999           '탕후루'의 배신…한입 깨물려던 순간 '딸기엔 곰팡이 활짝'
#
#                                          Original Link  \
# 0    https://www.yna.co.kr/view/AKR2024100214380005...
# 1    https://www.news1.kr/local/busan-gyeongnam/555...
# 2       https://www.nongmin.com/article/20241002500366
# 3    https://www.nocutnews.co.kr/news/6221828?utm_s...
# 4    http://www.gndomin.com/news/articleView.html?i...
# ..                                                 ...
# 995  https://www.kbmaeil.com/news/articleView.html?...
# 996  https://www.inews365.com/news/article.html?no=...
# 997     https://www.ajunews.com/view/20240730160339953
# 998  https://www.kukinews.com/article/view/kuk20240...
# 999        https://www.news1.kr/local/gyeonggi/5495842
#
#                                                   Link  \
# 0    https://n.news.naver.com/mnews/article/001/001...
# 1    https://n.news.naver.com/mnews/article/421/000...
# 2    https://n.news.naver.com/mnews/article/662/000...
# 3    https://n.news.naver.com/mnews/article/079/000...
# 4    http://www.gndomin.com/news/articleView.html?i...
# ..                                                 ...
# 995  https://www.kbmaeil.com/news/articleView.html?...
# 996  https://www.inews365.com/news/article.html?no=...
# 997     https://www.ajunews.com/view/20240730160339953
# 998  https://www.kukinews.com/article/view/kuk20240...
# 999  https://n.news.naver.com/mnews/article/421/000...
#
#                                            Description  \
# 0    대한민국 딸기 시배지인 경남 밀양시는 2일 시청 시장실에서 국내 처음으로 딸기를 재...
# 1    경남 밀양시가 국내 딸기 시배 유공자인 고 송준생 선생에게 공로패를 헌정했다. 시는...
# 2    경남 밀양시(시장 안병구)는 2일 시장실에서 우리나라에서 처음으로 딸기를 재배해 딸...
# 3    밀양시가 우리나라에서 처음으로 딸기를 재배해 딸기 농업의 기틀을 마련한 고(故) 송...
# 4    /밀양시 밀양시는 2일 시청 시장실에서 우리나라에서 처음으로 딸기를 재배해 딸기 농...
# ..                                                 ...
# 995  전국에서 찾아온 방문객들을 위한 부대행사로 딸기심기, 부추케이크 만들기 등 치유농업...
# 996  ［충북일보］ 충북대학교 38대 뮤즈 총동아리연합회가 지난 13일 청주시 상당구 가덕...
# 997  기후변화와 인력감소 문제 해결, 딸기 농가들 큰 호응 아주경제=산청=박연진 기자 c...
# 998  산청군의 ‘딸기 삽목 육모 신기술 보급사업’이 큰 호응을 얻고 있다. 30일 산청군...
# 999  카페에서 △딸기 탕후루 1개 △아메리카노 2잔 △그린티 1잔을 배달팁 500원을 포...
#
#                     Publication Date  \
# 0    Wed, 02 Oct 2024 16:58:00 +0900
# 1    Wed, 02 Oct 2024 18:07:00 +0900
# 2    Wed, 02 Oct 2024 17:20:00 +0900
# 3    Wed, 02 Oct 2024 17:25:00 +0900
# 4    Thu, 03 Oct 2024 17:30:00 +0900
# ..                               ...
# 995  Thu, 03 Oct 2024 20:00:00 +0900
# 996  Thu, 15 Aug 2024 14:04:00 +0900
# 997  Tue, 30 Jul 2024 16:14:00 +0900
# 998  Tue, 30 Jul 2024 15:52:00 +0900
# 999  Tue, 30 Jul 2024 15:11:00 +0900
#
#                                                Summary
# 0    경남 밀양시는 2일 시청에서 딸기 재배 선구자인 송준생 선생을 기리는 헌정식을 개최...
# 1    경남 밀양시가 국내 딸기 시배 유공자인 송준생 선생에게 공로패를 헌정했으며, 딸기 ...
# 2    밀양시 시장은 고 송준생 선생스럼 처음으로 딸기를 재배해 농업의 기초를 다지는 데 ...
# 3    밀양시가 우리나라 처음으로 딸기를 재배하여 딸기 농업의 초석을 놓은 고 송준생 선생...
# 4    밀양시는 고 송준생 선생을 기리기 위해 딸기 농업의 기초를 마련한 공로를 인정하여 ...
# ..                                                 ...
# 995  전국 방문객을 위한 부대행사로 딸기심기, 부추케이크 만들기 등의 치유농업 체험프로그...
# 996  충북대학교 38대 뮤즈 총동아리연합회가 청주시 상당구 가덕면에서 딸기를 수확하며 농...
# 997  산청군은 기후변화와 인력감소 문제를 해결하기 위해 딸기 농가들을 지원하기 위해 전략...
# 998  기후변화와 농촌인력감소로 육묘 시 인건비 상승, 고온성 병해와 해충 발생률 증가로 ...
# 999  카페에서 딸기 탕후루 1개, 아메리카노 2잔, 그린티 1잔을 주문한 A씨가 총 1만...
#
# [1000 rows x 6 columns]

# %%
# DataFrame을 CSV 파일로 저장
news_df.to_csv(f"news_df_summary_{keyword}.csv", index=False)

# %% [markdown]
# ### 뉴스의 일별 언급량에 따른 주식 가격 예측 (예정)
